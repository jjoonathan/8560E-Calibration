# %% [markdown]
# # YTF Calibration
# ![HP8565](RYTHM.jpg)

# %%
# Notebook Setup
import holoviews as hv
hv.extension('bokeh')
hv.renderer('bokeh').theme = 'dark_minimal'
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
from HP8560SweepResults import HP8560SweepResults
rslts = HP8560SweepResults.read_pickle('8565e_3943A01283/sweep27.pickle')
rslts.optim_bands(seed=42)
rslts.plt_optim_bands()
# Out:
# :Layout
#    .Overlay.I   :Overlay
#       .Image.I :Image   [GHz (band1),DAC]   (z)
#       .Curve.I :Curve   [GHz (band1)]   (y)
#    .Overlay.II  :Overlay
#       .Image.I :Image   [GHz (band2),DAC]   (z)
#       .Curve.I :Curve   [GHz (band2)]   (y)
#    .Overlay.III :Overlay
#       .Image.I :Image   [GHz (band3),DAC]   (z)
#       .Curve.I :Curve   [GHz (band3)]   (y)
#    .Overlay.IV  :Overlay
#       .Image.I :Image   [GHz (band4),DAC]   (z)
#       .Curve.I :Curve   [GHz (band4)]   (y)
#    .Overlay.V   :Overlay
#       .Image.I :Image   [GHz (band5),DAC]   (z)
#       .Curve.I :Curve   [GHz (band5)]   (y)

# %% [markdown]
# # Individual Band Diagnostics

# %%
rslts.plt_optim_convergence('band3', discrete=False, seed=42, initial_offset_=100) # initial_offset_  bad=128   good=100
# Out:
# :DynamicMap   [optimization_step//10]
#    :Overlay
#       .Image.I :Image   [GHz,DAC]   (z)
#       .Curve.I :Curve   [x]   (y)

# %%
rslts.plt_optim('band3', discrete=False, seed=42, initial_offset_=100)
# Out:
# :DynamicMap   [i]
#    :Layout
#       .Overlay.I  :Overlay
#          .Image.I :Image   [GHz,DAC]   (z)
#          .VLine.I :VLine   [x,y]
#          .Curve.I :Curve   [x]   (y)
#       .Overlay.II :Overlay
#          .Curve.I  :Curve   [DAC]   (dBm)
#          .Points.I :Points   [x,y]

# %% [markdown]
# # WRITE Calibration

# %%
# Generate and plot updated cal
from HP8560Eeprom import HP8560Eeprom

eep = HP8560Eeprom.from_file('sweep_283_01_eeprom.bin')
rslts.update_eeprom_ytf(eep)
# Out:
# :Overlay
#    .Curve.Band1 :Curve   [GHz]   (ytf)
#    .Curve.Band2 :Curve   [GHz]   (ytf)
#    .Curve.Band3 :Curve   [GHz]   (ytf)
#    .Curve.Band4 :Curve   [GHz]   (ytf)
#    .Curve.Band5 :Curve   [GHz]   (ytf)
#    .Curve.New1  :Curve   [GHz]   (ytf)
#    .Curve.New2  :Curve   [GHz]   (ytf)
#    .Curve.New3  :Curve   [GHz]   (ytf)
#    .Curve.New4  :Curve   [GHz]   (ytf)
#    .Curve.New5  :Curve   [GHz]   (ytf)

# %%
# Connect to SA
import vxi11
spec_an = vxi11.Instrument(host="ad007-left.lan", name="gpib0,18")
spec_an.clear()
print(f'{spec_an.ask("ID?")} {spec_an.ask("SER?")}')
# Out:
# HP8565E,007,008 3442A00248

# %%
# WRITE
eep.to_gpib(spec_an)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8192/8192 [03:05<00:00, 44.26it/s]
