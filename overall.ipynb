# %%
import holoviews as hv
hv.extension('bokeh')
hv.renderer('bokeh').theme = 'dark_minimal'
from HP8560Eeprom import HP8560Eeprom
from HP8560SweepResults import HP8560SweepResults
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# # 283

# %%
eep = HP8560Eeprom.from_file('8565e_3943A01283/8565e_3943A01283_eeprom.bin')
swp = HP8560SweepResults.read_pickle('8565e_3943A01283/sweep27.pickle')
swp.optim_bands(seed=42)
swp.update_eeprom_ytf(eep)
eep.plt()
# Out:
# :Layout
#    .Overlay.I  :Overlay
#       .Curve.Band0 :Curve   [GHz]   (dB)
#       .Curve.Band1 :Curve   [GHz]   (dB)
#       .Curve.Band2 :Curve   [GHz]   (dB)
#       .Curve.Band3 :Curve   [GHz]   (dB)
#       .Curve.Band4 :Curve   [GHz]   (dB)
#       .Curve.Band5 :Curve   [GHz]   (dB)
#       .Curve.New0  :Curve   [GHz]   (dB)
#       .Curve.New1  :Curve   [GHz]   (dB)
#       .Curve.New2  :Curve   [GHz]   (dB)
#       .Curve.New3  :Curve   [GHz]   (dB)
#       .Curve.New4  :Curve   [GHz]   (dB)
#       .Curve.New5  :Curve   [GHz]   (dB)
#    .Overlay.II :Overlay
#       .Curve.Band1 :Curve   [GHz]   (ytf)
#       .Curve.Band2 :Curve   [GHz]   (ytf)
#       .Curve.Band3 :Curve   [GHz]   (ytf)
#       .Curve.Band4 :Curve   [GHz]   (ytf)
#       .Curve.Band5 :Curve   [GHz]   (ytf)
#       .Curve.New1  :Curve   [GHz]   (ytf)
#       .Curve.New2  :Curve   [GHz]   (ytf)
#       .Curve.New3  :Curve   [GHz]   (ytf)
#       .Curve.New4  :Curve   [GHz]   (ytf)
# ...

# %% [markdown]
# # 248

# %%
eep = HP8560Eeprom.from_file('8565e_3442A00248/8565e_3442A00248_eeprom.bin')
swp = HP8560SweepResults.read_pickle('8565e_3442A00248/sweep_248_04.pickle')
swp.optim_bands(seed=42)
swp.update_eeprom_ytf(eep)
eep.plt()
# Out:
# :Layout
#    .Overlay.I  :Overlay
#       .Curve.Band0 :Curve   [GHz]   (dB)
#       .Curve.Band1 :Curve   [GHz]   (dB)
#       .Curve.Band2 :Curve   [GHz]   (dB)
#       .Curve.Band3 :Curve   [GHz]   (dB)
#       .Curve.Band4 :Curve   [GHz]   (dB)
#       .Curve.Band5 :Curve   [GHz]   (dB)
#       .Curve.New0  :Curve   [GHz]   (dB)
#       .Curve.New1  :Curve   [GHz]   (dB)
#       .Curve.New2  :Curve   [GHz]   (dB)
#       .Curve.New3  :Curve   [GHz]   (dB)
#       .Curve.New4  :Curve   [GHz]   (dB)
#       .Curve.New5  :Curve   [GHz]   (dB)
#    .Overlay.II :Overlay
#       .Curve.Band1 :Curve   [GHz]   (ytf)
#       .Curve.Band2 :Curve   [GHz]   (ytf)
#       .Curve.Band3 :Curve   [GHz]   (ytf)
#       .Curve.Band4 :Curve   [GHz]   (ytf)
#       .Curve.Band5 :Curve   [GHz]   (ytf)
#       .Curve.New1  :Curve   [GHz]   (ytf)
#       .Curve.New2  :Curve   [GHz]   (ytf)
#       .Curve.New3  :Curve   [GHz]   (ytf)
#       .Curve.New4  :Curve   [GHz]   (ytf)
# ...
